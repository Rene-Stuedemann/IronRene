# %% [markdown]
# # René's favorite holidays

# %% [markdown]
# My favorite holiday was when I visited Rom in Italy.

# %% [markdown]
# ## TOC:
# * [Input function](#first-bullet)
# * [Import Picture](#second-bullet)
# * [Import Bullet Points](#third-bullet)
# * [Text Formatting](#fourth-bullet)
# * [Import Video](#fith-bullet)

# %% [markdown]
# ## Input function <a class="anchor" id="first-bullet"></a>

# %%
name = input("Please enter my name: ")

# %% [markdown]
# ## Import Picture <a class="anchor" id="second-bullet"></a>

# %% [markdown]
# ![Rene_Rom.JPEG](attachment:Rene_Rom.JPEG)

# %%
city = input("Please enter my favorite city in Italy: ")
# Out:
# Please enter my favorite city in Italy: Rom

# %% [markdown]
# ![891.JPEG](attachment:891.JPEG)

# %% [markdown]
# ## Import Bullet Points <a class="anchor" id="third-bullet"></a>

# %% [markdown]
# ### Things I like to do in Rom:
# - Visiting the Colosseum underground
# - Exploring the acient ruins
# - Making a wish at the Trevi fountain

# %% [markdown]
# ## Text Formatting <a class="anchor" id="fourth-bullet"></a>

# %% [markdown]
# Try to make the text <p style="color:red;">colorful,</p> **bold** or *italic*.

# %% [markdown]
# ## Import Video <a class="anchor" id="fith-bullet"></a>

# %% [markdown]
# Here you can find a [Travel Guide](https://www.youtube.com/watch?v=DEJx0CYrDHk) for Rom.
