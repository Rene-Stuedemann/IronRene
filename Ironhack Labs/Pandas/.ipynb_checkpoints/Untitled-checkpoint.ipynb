# %%
ls
# Out:
#  Datenträger in Laufwerk C: ist OS
#  Volumeseriennummer: 7AD3-37CE
#
#  Verzeichnis von C:\Users\renes\Labs\Pandas
#
# 22.10.2021  14:26    <DIR>          .
# 22.10.2021  14:26    <DIR>          ..
# 22.10.2021  14:24    <DIR>          .ipynb_checkpoints
# 22.10.2021  10:12            88.430 health4all.csv
# 22.10.2021  14:24            31.971 Pandas.ipynb
# 22.10.2021  14:26               931 Untitled.ipynb
#                3 Datei(en),        121.332 Bytes
#                3 Verzeichnis(se), 302.240.108.544 Bytes frei

# %%
pwd
# Out:
# 'C:\\Users\\renes\\Labs\\Pandas'

# %%
# look/access in one folder above via '..'

ls ..
# Out:
#  Datenträger in Laufwerk C: ist OS
#  Volumeseriennummer: 7AD3-37CE
#
#  Verzeichnis von C:\Users\renes\Labs
#
# 22.10.2021  10:13    <DIR>          .
# 22.10.2021  10:13    <DIR>          ..
# 22.10.2021  09:47    <DIR>          .ipynb_checkpoints
# 19.10.2021  13:52    <DIR>          Jupyter
# 22.10.2021  09:47             3.301 Map stuff.ipynb
# 21.10.2021  19:44    <DIR>          Numpy
# 22.10.2021  14:30    <DIR>          Pandas
# 21.10.2021  19:45    <DIR>          PreWork Review
# 19.10.2021  14:14    <DIR>          Python
#                1 Datei(en),          3.301 Bytes
#                8 Verzeichnis(se), 302.239.096.832 Bytes frei

# %%
import pandas as pd

# %%
pd.read_csv('../health4all.csv')

# never use absolute paths!
# Out:
#      Unnamed: 0      id state gender   dob    avggift     hv1  \
# 0             0   44060    FL      M  1901  28.000000     NaN
# 1             1   96093    IL      M     0   5.666667   537.0
# 2             2   43333    FL      F  2501   4.111111   725.0
# 3             3   21885    NC      M  2208  27.277778     NaN
# 4             4  190108    FL      F     0   6.000000   995.0
# ..          ...     ...   ...    ...   ...        ...     ...
# 995         995   30104    GA      M  5201   8.833333   364.0
# 996         996  154614    CA      F     0  15.000000  1709.0
# 997         997   57151    KY      F  3601  15.900000   875.0
# 998         998   71425    MI      M  4401   6.000000   713.0
# 999        1001   41384    FL      F  5107   9.428571   556.0
#
#      med_house_income  avg_fam_income  hvp1    ic5  pobc1  pobc2  \
# 0                 392           520.0     7  21975      6     16
# 1                 365           473.0     0  19387      1     89
# ...
